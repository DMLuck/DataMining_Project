# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, RandomForestClassifier

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("kilohealth_app.csv", low_memory=False)
df
# Out:
#         client_id registration_dt  is_m1_retained       country  \
# 0           85299      2022-07-06               0           NaN
# 1           23959      2022-11-25               1           NaN
# 2           67300      2022-08-23               0           NaN
# 3           53164      2022-09-25               0           NaN
# 4           39700      2022-10-23               1           NaN
# ...           ...             ...             ...           ...
# 522971      65317      2022-08-28               1         Italy
# 522972      65317      2022-08-28               1         Italy
# 522973      26138      2022-11-21               0  South Africa
# 522974      26138      2022-11-21               0  South Africa
# 522975      26138      2022-11-21               0  South Africa
#
#        operating_system                     event_name  event_date  \
# 0                   NaN                            NaN         NaN
# 1                   NaN                            NaN         NaN
# 2                   NaN                            NaN         NaN
# 3                   NaN                            NaN         NaN
# 4                   NaN                            NaN         NaN
# ...                 ...                            ...         ...
# 522971              iOS  RunningPlan_Weight_Widget_Log  2022-09-08
# 522972              iOS  RunningPlan_Weight_Widget_Log  2022-08-31
# 522973              iOS  RunningPlan_Weight_Widget_Log  2022-11-30
# 522974              iOS  RunningPlan_Weight_Widget_Log  2022-11-26
# 522975              iOS  RunningPlan_Weight_Widget_Log  2022-12-01
#
#                        event_timestamp  time_zone_offset  distance  \
# 0                                  NaN               NaN       NaN
# 1                                  NaN               NaN       NaN
# 2                                  NaN               NaN       NaN
# 3                                  NaN               NaN       NaN
# 4                                  NaN               NaN       NaN
# ...                                ...               ...       ...
# 522971  2022-09-08 05:55:17.972006 UTC            7200.0       NaN
# 522972  2022-08-31 06:09:56.347006 UTC            7200.0       NaN
# 522973  2022-11-30 16:23:42.169005 UTC            7200.0       NaN
# 522974     2022-11-26 06:34:47.237 UTC            7200.0       NaN
# 522975  2022-12-01 08:55:47.715024 UTC            7200.0       NaN
#
#        event_category workout_difficulty run_mode feel_after_workout
# 0                 NaN                NaN      NaN                NaN
# 1                 NaN                NaN      NaN                NaN
# 2                 NaN                NaN      NaN                NaN
# 3                 NaN                NaN      NaN                NaN
# 4                 NaN                NaN      NaN                NaN
# ...               ...                ...      ...                ...
# 522971  weight_logged                NaN      NaN                NaN
# 522972  weight_logged                NaN      NaN                NaN
# 522973  weight_logged                NaN      NaN                NaN
# 522974  weight_logged                NaN      NaN                NaN
# 522975  weight_logged                NaN      NaN                NaN
#
# [522976 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# client_id                  0
# registration_dt            0
# is_m1_retained             0
# country                32380
# operating_system       32376
# event_name             32376
# event_date             32376
# event_timestamp        32376
# time_zone_offset       32376
# distance              307369
# event_category         46548
# workout_difficulty    317868
# run_mode              317868
# feel_after_workout    317868
# dtype: int64
